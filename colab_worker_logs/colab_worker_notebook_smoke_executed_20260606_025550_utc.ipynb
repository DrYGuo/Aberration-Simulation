# %% [markdown]
# # Colab Worker Notebook Smoke Test
#
# Small notebook used to verify headless notebook execution from the Colab worker.

# %%
from datetime import datetime, timezone
from pathlib import Path
import sys

print("notebook smoke ok")
print("utc", datetime.now(timezone.utc).isoformat())
print("python", sys.version.split()[0])
print("cwd", Path.cwd())
# Out:
# notebook smoke ok
# utc 2026-06-06T02:55:55.360697+00:00
# python 3.12.13
# cwd /content/Aberration-Simulation/notebooks
